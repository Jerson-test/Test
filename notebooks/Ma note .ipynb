# %%
>>> def indiquer_mon_nom():
... return 30;
...
>>> indiquer_mon_nom();
# Out:
#   File "<ipython-input-2-6f31cfc95b2a>", line 1
#     def indiquer_mon_nom();
#                           ^
# SyntaxError: invalid syntax
